# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\users\test\anaconda3\envs\pythondata\lib\site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\test\anaconda3\envs\pythondata\lib\site-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in c:\users\test\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\test\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (0.14.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in c:\users\test\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (1.18.3)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\test\anaconda3\envs\pythondata\lib\site-packages (0.14.1)

# %%
import pandas as pd

# %% [markdown]
#  ## Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Select your features (columns)

# %%
# Set features. This will also be used as your x values.
X = df.drop(columns='koi_disposition')
y = df['koi_disposition']

# %%
# Determine which inputs to keep
from sklearn.ensemble import ExtraTreesClassifier

model = ExtraTreesClassifier()
model.fit(X,y)
#print(model.feature_importances_)

feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(40)
# Out:
# C:\Users\test\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# koi_fpflag_ss        0.153734
# koi_fpflag_co        0.140230
# koi_fpflag_nt        0.136469
# koi_fpflag_ec        0.034427
# koi_model_snr        0.029439
# koi_prad             0.026724
# koi_duration_err1    0.025929
# koi_time0bk_err2     0.025609
# koi_duration_err2    0.024197
# koi_time0bk_err1     0.021174
# koi_depth            0.020137
# koi_period           0.017949
# koi_steff_err1       0.017799
# koi_slogg_err2       0.017483
# koi_prad_err2        0.016247
# koi_steff_err2       0.015951
# koi_time0bk          0.015849
# koi_depth_err2       0.015736
# koi_tce_plnt_num     0.014788
# koi_duration         0.014540
# koi_steff            0.013714
# koi_prad_err1        0.013471
# koi_impact           0.013457
# koi_depth_err1       0.013301
# koi_teq              0.012685
# koi_slogg            0.011536
# koi_impact_err1      0.011328
# koi_period_err1      0.011127
# koi_slogg_err1       0.011004
# koi_period_err2      0.010787
# ra                   0.010542
# dec                  0.009975
# koi_srad_err1        0.009561
# koi_srad             0.009435
# koi_srad_err2        0.009282
# koi_kepmag           0.009067
# koi_insol            0.009048
# koi_insol_err1       0.008969
# koi_impact_err2      0.008871
# koi_insol_err2       0.008431
# dtype: float64

# %%
# After testing, taking the top 16 weighted inputs
Xsel = df[['koi_fpflag_co', 'koi_fpflag_ss', 'koi_fpflag_nt', 'koi_model_snr', 'koi_fpflag_ec', 
           'koi_duration_err2', 'koi_steff_err1', 'koi_slogg_err2', 'koi_time0bk_err1', 'koi_teq',
           'koi_time0bk_err2', 'koi_duration_err1', 'koi_depth', 'koi_depth_err2', 'koi_period',
           'koi_duration','koi_prad']]
Xsel
# Out:
#       koi_fpflag_co  koi_fpflag_ss  koi_fpflag_nt  koi_model_snr  \
# 0                 0              0              0           25.8
# 1                 0              1              0           76.3
# 2                 0              1              0          505.6
# 3                 0              0              0           40.9
# 4                 0              0              0           40.2
# ...             ...            ...            ...            ...
# 6986              0              0              0            8.4
# 6987              1              1              0          453.3
# 6988              0              0              0           10.6
# 6989              1              0              0           12.3
# 6990              1              0              0            8.2
#
#       koi_fpflag_ec  koi_duration_err2  koi_steff_err1  koi_slogg_err2  \
# 0                 0           -0.11600              81          -0.096
# 1                 0           -0.03410             158          -0.176
# 2                 0           -0.00537             157          -0.168
# 3                 0           -0.04200             169          -0.210
# 4                 0           -0.06730             189          -0.229
# ...             ...                ...             ...             ...
# 6986              1           -0.63400             169          -0.189
# 6987              0           -0.01740             139          -0.196
# 6988              0           -0.22900             165          -0.224
# 6989              0           -0.16200             193          -0.224
# 6990              1           -0.28300             158          -0.216
#
#       koi_time0bk_err1  koi_teq  koi_time0bk_err2  koi_duration_err1  \
# 0             0.003520      443         -0.003520            0.11600
# 1             0.000581      638         -0.000581            0.03410
# 2             0.000115     1395         -0.000115            0.00537
# 3             0.001130     1406         -0.001130            0.04200
# 4             0.001900     1160         -0.001900            0.06730
# ...                ...      ...               ...                ...
# 6986          0.015700      929         -0.015700            0.63400
# 6987          0.000170     2088         -0.000170            0.01740
# 6988          0.007690     1608         -0.007690            0.22900
# 6989          0.002850     2218         -0.002850            0.16200
# 6990          0.010800     1266         -0.010800            0.28300
#
#       koi_depth  koi_depth_err2  koi_period  koi_duration  koi_prad
# 0         874.8           -35.5   54.418383       4.50700      2.83
# 1       10829.0          -171.0   19.899140       1.78220     14.60
# 2        8079.2           -12.8    1.736952       2.40641     33.46
# 3         603.3           -16.9    2.525592       1.65450      2.75
# 4         686.0           -18.7    4.134435       3.14020      2.77
# ...         ...             ...         ...           ...       ...
# 6986       87.7           -13.0    8.589871       4.80600      1.11
# 6987     1579.2            -4.6    0.527699       3.22210     29.35
# 6988       48.5            -5.4    1.739849       3.11400      0.72
# 6989      103.6           -14.7    0.681402       0.86500      1.07
# 6990       76.7           -10.8    4.856035       3.07800      1.05
#
# [6991 rows x 17 columns]

# %% [markdown]
# ## Create a Train Test Split
# *Use koi_disposition for the y values*

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(Xsel, y, random_state = 1, stratify = y)

# %% [markdown]
# ## Pre-processing
# *Scale the data using the MinMaxScaler and perform some feature selection*

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler

X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Train the Model
# ---------------

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
print(f"Training Data Score: {clf.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {clf.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.8443935926773455

# %% [markdown]
# ## Hyperparameter Tuning
# *Use GridSearchCV to tune the model's parameters*

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV

param_grid = {'min_samples_split': [0.1, 0.15, .00001, .001, .99],
             'min_samples_leaf': [1, 2, 25, 49, 10, 20]}


grid = GridSearchCV(clf, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled,y_train)
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# [CV] min_samples_leaf=1, min_samples_split=0.1 .......................
# [CV]  min_samples_leaf=1, min_samples_split=0.1, score=0.878, total=   0.0s
# [CV] min_samples_leaf=1, min_samples_split=0.1 .......................
# [CV]  min_samples_leaf=1, min_samples_split=0.1, score=0.880, total=   0.0s
# [CV] min_samples_leaf=1, min_samples_split=0.1 .......................
# [CV]  min_samples_leaf=1, min_samples_split=0.1, score=0.882, total=   0.0s
# [CV] min_samples_leaf=1, min_samples_split=0.15 ......................
# C:\Users\test\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [CV]  min_samples_leaf=1, min_samples_split=0.15, score=0.878, total=   0.0s
# [CV] min_samples_leaf=1, min_samples_split=0.15 ......................
# [CV]  min_samples_leaf=1, min_samples_split=0.15, score=0.881, total=   0.0s
# [CV] min_samples_leaf=1, min_samples_split=0.15 ......................
# [CV]  min_samples_leaf=1, min_samples_split=0.15, score=0.881, total=   0.0s
# [CV] min_samples_leaf=1, min_samples_split=1e-05 .....................
# [CV]  min_samples_leaf=1, min_samples_split=1e-05, score=0.853, total=   0.1s
# [CV] min_samples_leaf=1, min_samples_split=1e-05 .....................
# [CV]  min_samples_leaf=1, min_samples_split=1e-05, score=0.851, total=   0.1s
# [CV] min_samples_leaf=1, min_samples_split=1e-05 .....................
# [CV]  min_samples_leaf=1, min_samples_split=1e-05, score=0.847, total=   0.0s
# [CV] min_samples_leaf=1, min_samples_split=0.001 .....................
# [CV]  min_samples_leaf=1, min_samples_split=0.001, score=0.851, total=   0.1s
# [CV] min_samples_leaf=1, min_samples_split=0.001 .....................
# [CV]  min_samples_leaf=1, min_samples_split=0.001, score=0.851, total=   0.0s
# [CV] min_samples_leaf=1, min_samples_split=0.001 .....................
# [CV]  min_samples_leaf=1, min_samples_split=0.001, score=0.844, total=   0.1s
# [CV] min_samples_leaf=1, min_samples_split=0.99 ......................
# [CV]  min_samples_leaf=1, min_samples_split=0.99, score=0.501, total=   0.0s
# [CV] min_samples_leaf=1, min_samples_split=0.99 ......................
# [CV]  min_samples_leaf=1, min_samples_split=0.99, score=0.501, total=   0.0s
# [CV] min_samples_leaf=1, min_samples_split=0.99 ......................
# [CV]  min_samples_leaf=1, min_samples_split=0.99, score=0.501, total=   0.0s
# [CV] min_samples_leaf=2, min_samples_split=0.1 .......................
# [CV]  min_samples_leaf=2, min_samples_split=0.1, score=0.879, total=   0.0s
# [CV] min_samples_leaf=2, min_samples_split=0.1 .......................
# [CV]  min_samples_leaf=2, min_samples_split=0.1, score=0.879, total=   0.0s
# [CV] min_samples_leaf=2, min_samples_split=0.1 .......................
# [CV]  min_samples_leaf=2, min_samples_split=0.1, score=0.881, total=   0.0s
# [CV] min_samples_leaf=2, min_samples_split=0.15 ......................
# [CV]  min_samples_leaf=2, min_samples_split=0.15, score=0.878, total=   0.0s
# [CV] min_samples_leaf=2, min_samples_split=0.15 ......................
# [CV]  min_samples_leaf=2, min_samples_split=0.15, score=0.881, total=   0.0s
# [CV] min_samples_leaf=2, min_samples_split=0.15 ......................
# [CV]  min_samples_leaf=2, min_samples_split=0.15, score=0.881, total=   0.0s
# [CV] min_samples_leaf=2, min_samples_split=1e-05 .....................
# [CV]  min_samples_leaf=2, min_samples_split=1e-05, score=0.852, total=   0.0s
# [CV] min_samples_leaf=2, min_samples_split=1e-05 .....................
# [CV]  min_samples_leaf=2, min_samples_split=1e-05, score=0.847, total=   0.0s
# [CV] min_samples_leaf=2, min_samples_split=1e-05 .....................
# [CV]  min_samples_leaf=2, min_samples_split=1e-05, score=0.860, total=   0.0s
# [CV] min_samples_leaf=2, min_samples_split=0.001 .....................
# [CV]  min_samples_leaf=2, min_samples_split=0.001, score=0.848, total=   0.0s
# [CV] min_samples_leaf=2, min_samples_split=0.001 .....................
# [CV]  min_samples_leaf=2, min_samples_split=0.001, score=0.856, total=   0.0s
# [CV] min_samples_leaf=2, min_samples_split=0.001 .....................
# [CV]  min_samples_leaf=2, min_samples_split=0.001, score=0.861, total=   0.1s
# [CV] min_samples_leaf=2, min_samples_split=0.99 ......................
# [CV]  min_samples_leaf=2, min_samples_split=0.99, score=0.501, total=   0.0s
# [CV] min_samples_leaf=2, min_samples_split=0.99 ......................
# [CV]  min_samples_leaf=2, min_samples_split=0.99, score=0.501, total=   0.0s
# [CV] min_samples_leaf=2, min_samples_split=0.99 ......................
# [CV]  min_samples_leaf=2, min_samples_split=0.99, score=0.501, total=   0.0s
# [CV] min_samples_leaf=25, min_samples_split=0.1 ......................
# [CV]  min_samples_leaf=25, min_samples_split=0.1, score=0.874, total=   0.0s
# [CV] min_samples_leaf=25, min_samples_split=0.1 ......................
# [CV]  min_samples_leaf=25, min_samples_split=0.1, score=0.872, total=   0.0s
# [CV] min_samples_leaf=25, min_samples_split=0.1 ......................
# [CV]  min_samples_leaf=25, min_samples_split=0.1, score=0.867, total=   0.0s
# [CV] min_samples_leaf=25, min_samples_split=0.15 .....................
# [CV]  min_samples_leaf=25, min_samples_split=0.15, score=0.874, total=   0.0s
# [CV] min_samples_leaf=25, min_samples_split=0.15 .....................
# [CV]  min_samples_leaf=25, min_samples_split=0.15, score=0.872, total=   0.0s
# [CV] min_samples_leaf=25, min_samples_split=0.15 .....................
# [CV]  min_samples_leaf=25, min_samples_split=0.15, score=0.867, total=   0.0s
# [CV] min_samples_leaf=25, min_samples_split=1e-05 ....................
# [CV]  min_samples_leaf=25, min_samples_split=1e-05, score=0.876, total=   0.0s
# [CV] min_samples_leaf=25, min_samples_split=1e-05 ....................
# [CV]  min_samples_leaf=25, min_samples_split=1e-05, score=0.875, total=   0.0s
# [CV] min_samples_leaf=25, min_samples_split=1e-05 ....................
# [CV]  min_samples_leaf=25, min_samples_split=1e-05, score=0.866, total=   0.0s
# [CV] min_samples_leaf=25, min_samples_split=0.001 ....................
# [CV]  min_samples_leaf=25, min_samples_split=0.001, score=0.876, total=   0.0s
# [CV] min_samples_leaf=25, min_samples_split=0.001 ....................
# [CV]  min_samples_leaf=25, min_samples_split=0.001, score=0.875, total=   0.0s
# [CV] min_samples_leaf=25, min_samples_split=0.001 ....................
# [CV]  min_samples_leaf=25, min_samples_split=0.001, score=0.866, total=   0.0s
# [CV] min_samples_leaf=25, min_samples_split=0.99 .....................
# [CV]  min_samples_leaf=25, min_samples_split=0.99, score=0.501, total=   0.0s
# [CV] min_samples_leaf=25, min_samples_split=0.99 .....................
# [CV]  min_samples_leaf=25, min_samples_split=0.99, score=0.501, total=   0.0s
# [CV] min_samples_leaf=25, min_samples_split=0.99 .....................
# [CV]  min_samples_leaf=25, min_samples_split=0.99, score=0.501, total=   0.0s
# [CV] min_samples_leaf=49, min_samples_split=0.1 ......................
# [CV]  min_samples_leaf=49, min_samples_split=0.1, score=0.868, total=   0.0s
# [CV] min_samples_leaf=49, min_samples_split=0.1 ......................
# [CV]  min_samples_leaf=49, min_samples_split=0.1, score=0.871, total=   0.0s
# [CV] min_samples_leaf=49, min_samples_split=0.1 ......................
# [CV]  min_samples_leaf=49, min_samples_split=0.1, score=0.866, total=   0.0s
# [CV] min_samples_leaf=49, min_samples_split=0.15 .....................
# [CV]  min_samples_leaf=49, min_samples_split=0.15, score=0.868, total=   0.0s
# [CV] min_samples_leaf=49, min_samples_split=0.15 .....................
# [CV]  min_samples_leaf=49, min_samples_split=0.15, score=0.871, total=   0.0s
# [CV] min_samples_leaf=49, min_samples_split=0.15 .....................
# [CV]  min_samples_leaf=49, min_samples_split=0.15, score=0.866, total=   0.0s
# [CV] min_samples_leaf=49, min_samples_split=1e-05 ....................
# [CV]  min_samples_leaf=49, min_samples_split=1e-05, score=0.875, total=   0.0s
# [CV] min_samples_leaf=49, min_samples_split=1e-05 ....................
# [CV]  min_samples_leaf=49, min_samples_split=1e-05, score=0.870, total=   0.0s
# [CV] min_samples_leaf=49, min_samples_split=1e-05 ....................
# [CV]  min_samples_leaf=49, min_samples_split=1e-05, score=0.871, total=   0.0s
# [CV] min_samples_leaf=49, min_samples_split=0.001 ....................
# [CV]  min_samples_leaf=49, min_samples_split=0.001, score=0.875, total=   0.0s
# [CV] min_samples_leaf=49, min_samples_split=0.001 ....................
# [CV]  min_samples_leaf=49, min_samples_split=0.001, score=0.870, total=   0.0s
# [CV] min_samples_leaf=49, min_samples_split=0.001 ....................
# [CV]  min_samples_leaf=49, min_samples_split=0.001, score=0.871, total=   0.0s
# [CV] min_samples_leaf=49, min_samples_split=0.99 .....................
# [CV]  min_samples_leaf=49, min_samples_split=0.99, score=0.501, total=   0.0s
# [CV] min_samples_leaf=49, min_samples_split=0.99 .....................
# [CV]  min_samples_leaf=49, min_samples_split=0.99, score=0.501, total=   0.0s
# [CV] min_samples_leaf=49, min_samples_split=0.99 .....................
# [CV]  min_samples_leaf=49, min_samples_split=0.99, score=0.501, total=   0.0s
# [CV] min_samples_leaf=10, min_samples_split=0.1 ......................
# [CV]  min_samples_leaf=10, min_samples_split=0.1, score=0.878, total=   0.0s
# [CV] min_samples_leaf=10, min_samples_split=0.1 ......................
# [CV]  min_samples_leaf=10, min_samples_split=0.1, score=0.881, total=   0.0s
# [CV] min_samples_leaf=10, min_samples_split=0.1 ......................
# [CV]  min_samples_leaf=10, min_samples_split=0.1, score=0.881, total=   0.0s
# [CV] min_samples_leaf=10, min_samples_split=0.15 .....................
# [CV]  min_samples_leaf=10, min_samples_split=0.15, score=0.878, total=   0.0s
# [CV] min_samples_leaf=10, min_samples_split=0.15 .....................
# [CV]  min_samples_leaf=10, min_samples_split=0.15, score=0.881, total=   0.0s
# [CV] min_samples_leaf=10, min_samples_split=0.15 .....................
# [CV]  min_samples_leaf=10, min_samples_split=0.15, score=0.881, total=   0.0s
# [CV] min_samples_leaf=10, min_samples_split=1e-05 ....................
# [CV]  min_samples_leaf=10, min_samples_split=1e-05, score=0.863, total=   0.0s
# [CV] min_samples_leaf=10, min_samples_split=1e-05 ....................
# [CV]  min_samples_leaf=10, min_samples_split=1e-05, score=0.884, total=   0.0s
# [CV] min_samples_leaf=10, min_samples_split=1e-05 ....................
# [CV]  min_samples_leaf=10, min_samples_split=1e-05, score=0.875, total=   0.0s
# [CV] min_samples_leaf=10, min_samples_split=0.001 ....................
# [CV]  min_samples_leaf=10, min_samples_split=0.001, score=0.860, total=   0.0s
# [CV] min_samples_leaf=10, min_samples_split=0.001 ....................
# [CV]  min_samples_leaf=10, min_samples_split=0.001, score=0.884, total=   0.0s
# [CV] min_samples_leaf=10, min_samples_split=0.001 ....................
# [CV]  min_samples_leaf=10, min_samples_split=0.001, score=0.879, total=   0.0s
# [CV] min_samples_leaf=10, min_samples_split=0.99 .....................
# [CV]  min_samples_leaf=10, min_samples_split=0.99, score=0.501, total=   0.0s
# [CV] min_samples_leaf=10, min_samples_split=0.99 .....................
# [CV]  min_samples_leaf=10, min_samples_split=0.99, score=0.501, total=   0.0s
# [CV] min_samples_leaf=10, min_samples_split=0.99 .....................
# [CV]  min_samples_leaf=10, min_samples_split=0.99, score=0.501, total=   0.0s
# [CV] min_samples_leaf=20, min_samples_split=0.1 ......................
# [CV]  min_samples_leaf=20, min_samples_split=0.1, score=0.877, total=   0.0s
# [CV] min_samples_leaf=20, min_samples_split=0.1 ......................
# [CV]  min_samples_leaf=20, min_samples_split=0.1, score=0.882, total=   0.0s
# [CV] min_samples_leaf=20, min_samples_split=0.1 ......................
# [CV]  min_samples_leaf=20, min_samples_split=0.1, score=0.875, total=   0.0s
# [CV] min_samples_leaf=20, min_samples_split=0.15 .....................
# [CV]  min_samples_leaf=20, min_samples_split=0.15, score=0.877, total=   0.0s
# [CV] min_samples_leaf=20, min_samples_split=0.15 .....................
# [CV]  min_samples_leaf=20, min_samples_split=0.15, score=0.882, total=   0.0s
# [CV] min_samples_leaf=20, min_samples_split=0.15 .....................
# [CV]  min_samples_leaf=20, min_samples_split=0.15, score=0.875, total=   0.0s
# [CV] min_samples_leaf=20, min_samples_split=1e-05 ....................
# [CV]  min_samples_leaf=20, min_samples_split=1e-05, score=0.869, total=   0.0s
# [CV] min_samples_leaf=20, min_samples_split=1e-05 ....................
# [CV]  min_samples_leaf=20, min_samples_split=1e-05, score=0.878, total=   0.0s
# [CV] min_samples_leaf=20, min_samples_split=1e-05 ....................
# [CV]  min_samples_leaf=20, min_samples_split=1e-05, score=0.871, total=   0.0s
# [CV] min_samples_leaf=20, min_samples_split=0.001 ....................
# [CV]  min_samples_leaf=20, min_samples_split=0.001, score=0.869, total=   0.0s
# [CV] min_samples_leaf=20, min_samples_split=0.001 ....................
# [CV]  min_samples_leaf=20, min_samples_split=0.001, score=0.878, total=   0.0s
# [CV] min_samples_leaf=20, min_samples_split=0.001 ....................
# [CV]  min_samples_leaf=20, min_samples_split=0.001, score=0.873, total=   0.0s
# [CV] min_samples_leaf=20, min_samples_split=0.99 .....................
# [CV]  min_samples_leaf=20, min_samples_split=0.99, score=0.501, total=   0.0s
# [CV] min_samples_leaf=20, min_samples_split=0.99 .....................
# [CV]  min_samples_leaf=20, min_samples_split=0.99, score=0.501, total=   0.0s
# [CV] min_samples_leaf=20, min_samples_split=0.99 .....................
# [CV]  min_samples_leaf=20, min_samples_split=0.99, score=0.501, total=   0.0s
# [Parallel(n_jobs=1)]: Done  90 out of  90 | elapsed:    2.7s finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=DecisionTreeClassifier(class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort=False, random_state=None,
#                                               splitter='best'),
#              iid='warn', n_jobs=None,
#              param_grid={'min_samples_leaf': [1, 2, 25, 49, 10, 20],
#                          'min_samples_split': [0.1, 0.15, 1e-05, 0.001, 0.99]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'min_samples_leaf': 1, 'min_samples_split': 0.15}
# 0.8800305168796491

# %% [markdown]
# ## Save the Model
# ----------------

# %%
import joblib
filename = 'Model_Files/Trees.sav'
joblib.dump(grid, filename)
# Out:
# ['Model_Files/Trees.sav']
