# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\users\test\anaconda3\envs\pythondata\lib\site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\test\anaconda3\envs\pythondata\lib\site-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\test\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (0.14.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in c:\users\test\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (1.18.4)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in c:\users\test\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (1.4.1)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\test\anaconda3\envs\pythondata\lib\site-packages (0.14.1)

# %%
import pandas as pd

# %% [markdown]
#  ## Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Select your features (columns)

# %%
# Set features. This will also be used as your x values.
X = df.drop(columns='koi_disposition')
y = df['koi_disposition']

# %%
# Determine which inputs to keep
from sklearn.ensemble import ExtraTreesClassifier

model = ExtraTreesClassifier()
model.fit(X,y)
#print(model.feature_importances_)

feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(40)
# Out:
# C:\Users\test\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# koi_fpflag_ss        0.166305
# koi_fpflag_nt        0.128145
# koi_fpflag_co        0.124459
# koi_fpflag_ec        0.063265
# koi_model_snr        0.031402
# koi_steff_err1       0.029730
# koi_time0bk_err1     0.029331
# koi_duration_err2    0.028617
# koi_duration_err1    0.021740
# koi_depth_err2       0.019389
# koi_time0bk_err2     0.018516
# koi_duration         0.017389
# koi_steff_err2       0.016769
# koi_time0bk          0.015119
# koi_depth            0.014835
# koi_prad_err1        0.014189
# koi_tce_plnt_num     0.013790
# koi_impact_err1      0.013717
# koi_period_err2      0.013554
# koi_impact           0.013322
# koi_period_err1      0.013238
# koi_prad             0.012673
# koi_slogg_err2       0.012659
# koi_period           0.012515
# koi_slogg_err1       0.011944
# koi_depth_err1       0.011860
# koi_prad_err2        0.011644
# koi_teq              0.011425
# koi_srad_err1        0.011178
# ra                   0.010504
# koi_impact_err2      0.010347
# koi_kepmag           0.009649
# dec                  0.008762
# koi_slogg            0.008709
# koi_insol            0.008671
# koi_srad_err2        0.008512
# koi_steff            0.008511
# koi_insol_err2       0.008392
# koi_insol_err1       0.007825
# koi_srad             0.007402
# dtype: float64

# %%
# After testing, taking the top 16 weighted inputs
# Xsel = df[['koi_fpflag_co', 'koi_fpflag_ss', 'koi_fpflag_nt', 'koi_model_snr', 'koi_fpflag_ec', 
#            'koi_duration_err2', 'koi_steff_err1', 'koi_slogg_err2', 'koi_time0bk_err1', 'koi_teq',
#            'koi_time0bk_err2', 'koi_duration_err1', 'koi_depth', 'koi_depth_err2', 'koi_period',
#            'koi_duration','koi_prad']]
# Xsel
Xsel = X.drop(['koi_impact_err2', 'koi_depth_err1', 'koi_depth_err2', 'koi_insol_err2', 'koi_prad_err2',
              'koi_insol', 'koi_prad', 'koi_prad_err1', 'koi_insol_err1', 'koi_kepmag', 'koi_time0bk',
              'koi_srad', 'koi_steff', 'koi_srad_err2', 'dec', 'ra', 'koi_teq', 'koi_slogg_err1'], axis=1)
Xsel
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0   54.418383
# 1                 0              1              0              0   19.899140
# 2                 0              1              0              0    1.736952
# 3                 0              0              0              0    2.525592
# 4                 0              0              0              0    4.134435
# ...             ...            ...            ...            ...         ...
# 6986              0              0              0              1    8.589871
# 6987              0              1              1              0    0.527699
# 6988              0              0              0              0    1.739849
# 6989              0              0              1              0    0.681402
# 6990              0              0              1              1    4.856035
#
#       koi_period_err1  koi_period_err2  koi_time0bk_err1  koi_time0bk_err2  \
# 0        2.479000e-04    -2.479000e-04          0.003520         -0.003520
# 1        1.490000e-05    -1.490000e-05          0.000581         -0.000581
# 2        2.630000e-07    -2.630000e-07          0.000115         -0.000115
# 3        3.760000e-06    -3.760000e-06          0.001130         -0.001130
# 4        1.050000e-05    -1.050000e-05          0.001900         -0.001900
# ...               ...              ...               ...               ...
# 6986     1.846000e-04    -1.846000e-04          0.015700         -0.015700
# 6987     1.160000e-07    -1.160000e-07          0.000170         -0.000170
# 6988     1.780000e-05    -1.780000e-05          0.007690         -0.007690
# 6989     2.430000e-06    -2.430000e-06          0.002850         -0.002850
# 6990     6.360000e-05    -6.360000e-05          0.010800         -0.010800
#
#       koi_impact  ...  koi_duration_err1  koi_duration_err2  koi_depth  \
# 0          0.586  ...            0.11600           -0.11600      874.8
# 1          0.969  ...            0.03410           -0.03410    10829.0
# 2          1.276  ...            0.00537           -0.00537     8079.2
# 3          0.701  ...            0.04200           -0.04200      603.3
# 4          0.762  ...            0.06730           -0.06730      686.0
# ...          ...  ...                ...                ...        ...
# 6986       0.765  ...            0.63400           -0.63400       87.7
# 6987       1.252  ...            0.01740           -0.01740     1579.2
# 6988       0.043  ...            0.22900           -0.22900       48.5
# 6989       0.147  ...            0.16200           -0.16200      103.6
# 6990       0.134  ...            0.28300           -0.28300       76.7
#
#       koi_model_snr  koi_tce_plnt_num  koi_steff_err1  koi_steff_err2  \
# 0              25.8                 2              81             -81
# 1              76.3                 1             158            -176
# 2             505.6                 1             157            -174
# 3              40.9                 1             169            -211
# 4              40.2                 2             189            -232
# ...             ...               ...             ...             ...
# 6986            8.4                 1             169            -152
# 6987          453.3                 1             139            -166
# 6988           10.6                 1             165            -220
# 6989           12.3                 1             193            -236
# 6990            8.2                 1             158            -225
#
#       koi_slogg  koi_slogg_err2  koi_srad_err1
# 0         4.467          -0.096          0.105
# 1         4.544          -0.176          0.233
# 2         4.564          -0.168          0.201
# 3         4.438          -0.210          0.334
# 4         4.486          -0.229          0.315
# ...         ...             ...            ...
# 6986      4.296          -0.189          0.313
# 6987      4.529          -0.196          0.237
# 6988      4.444          -0.224          0.341
# 6989      4.447          -0.224          0.341
# 6990      4.385          -0.216          0.410
#
# [6991 rows x 22 columns]

# %% [markdown]
# ## Create a Train Test Split
# *Use koi_disposition for the y values*

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(Xsel, y, random_state = 1, stratify = y)

# %% [markdown]
# ## Pre-processing
# *Scale the data using the MinMaxScaler and perform some feature selection*

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler

X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Train the Model
# ---------------

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
print(f"Training Data Score: {clf.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {clf.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.8569794050343249

# %% [markdown]
# ## Hyperparameter Tuning
# *Use GridSearchCV to tune the model's parameters*

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV

param_grid = {'max_depth': [5, 7, 8], 'min_weight_fraction_leaf': [.00001],
             'min_samples_split': [0.15, .185]}


grid = GridSearchCV(clf, param_grid, verbose=3)

# %%
# Train the model with GridSearch
gs = grid.fit(X_train_scaled,y_train)
# Out:
# C:\Users\test\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [CV] max_depth=5, min_samples_split=0.15, min_weight_fraction_leaf=1e-05
# [CV]  max_depth=5, min_samples_split=0.15, min_weight_fraction_leaf=1e-05, score=0.879, total=   0.0s
# [CV] max_depth=5, min_samples_split=0.15, min_weight_fraction_leaf=1e-05
# [CV]  max_depth=5, min_samples_split=0.15, min_weight_fraction_leaf=1e-05, score=0.879, total=   0.0s
# [CV] max_depth=5, min_samples_split=0.15, min_weight_fraction_leaf=1e-05
# [CV]  max_depth=5, min_samples_split=0.15, min_weight_fraction_leaf=1e-05, score=0.882, total=   0.0s
# [CV] max_depth=5, min_samples_split=0.185, min_weight_fraction_leaf=1e-05
# [CV]  max_depth=5, min_samples_split=0.185, min_weight_fraction_leaf=1e-05, score=0.879, total=   0.0s
# [CV] max_depth=5, min_samples_split=0.185, min_weight_fraction_leaf=1e-05
# [CV]  max_depth=5, min_samples_split=0.185, min_weight_fraction_leaf=1e-05, score=0.879, total=   0.0s
# [CV] max_depth=5, min_samples_split=0.185, min_weight_fraction_leaf=1e-05
# [CV]  max_depth=5, min_samples_split=0.185, min_weight_fraction_leaf=1e-05, score=0.880, total=   0.0s
# [CV] max_depth=7, min_samples_split=0.15, min_weight_fraction_leaf=1e-05
# [CV]  max_depth=7, min_samples_split=0.15, min_weight_fraction_leaf=1e-05, score=0.888, total=   0.0s
# [CV] max_depth=7, min_samples_split=0.15, min_weight_fraction_leaf=1e-05
# [CV]  max_depth=7, min_samples_split=0.15, min_weight_fraction_leaf=1e-05, score=0.887, total=   0.0s
# [CV] max_depth=7, min_samples_split=0.15, min_weight_fraction_leaf=1e-05
# [CV]  max_depth=7, min_samples_split=0.15, min_weight_fraction_leaf=1e-05, score=0.883, total=   0.0s
# [CV] max_depth=7, min_samples_split=0.185, min_weight_fraction_leaf=1e-05
# [CV]  max_depth=7, min_samples_split=0.185, min_weight_fraction_leaf=1e-05, score=0.888, total=   0.0s
# [CV] max_depth=7, min_samples_split=0.185, min_weight_fraction_leaf=1e-05
# [CV]  max_depth=7, min_samples_split=0.185, min_weight_fraction_leaf=1e-05, score=0.887, total=   0.0s
# [CV] max_depth=7, min_samples_split=0.185, min_weight_fraction_leaf=1e-05
# [CV]  max_depth=7, min_samples_split=0.185, min_weight_fraction_leaf=1e-05, score=0.882, total=   0.0s
# [CV] max_depth=8, min_samples_split=0.15, min_weight_fraction_leaf=1e-05
# [CV]  max_depth=8, min_samples_split=0.15, min_weight_fraction_leaf=1e-05, score=0.888, total=   0.0s
# [CV] max_depth=8, min_samples_split=0.15, min_weight_fraction_leaf=1e-05
# [CV]  max_depth=8, min_samples_split=0.15, min_weight_fraction_leaf=1e-05, score=0.887, total=   0.0s
# [CV] max_depth=8, min_samples_split=0.15, min_weight_fraction_leaf=1e-05
# [CV]  max_depth=8, min_samples_split=0.15, min_weight_fraction_leaf=1e-05, score=0.883, total=   0.0s
# [CV] max_depth=8, min_samples_split=0.185, min_weight_fraction_leaf=1e-05
# [CV]  max_depth=8, min_samples_split=0.185, min_weight_fraction_leaf=1e-05, score=0.888, total=   0.0s
# [CV] max_depth=8, min_samples_split=0.185, min_weight_fraction_leaf=1e-05
# [CV]  max_depth=8, min_samples_split=0.185, min_weight_fraction_leaf=1e-05, score=0.887, total=   0.0s
# [CV] max_depth=8, min_samples_split=0.185, min_weight_fraction_leaf=1e-05
# [CV]  max_depth=8, min_samples_split=0.185, min_weight_fraction_leaf=1e-05, score=0.882, total=   0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    0.5s finished

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'max_depth': 7, 'min_samples_split': 0.15, 'min_weight_fraction_leaf': 1e-05}
# 0.8861338928094602

# %%
predictions = gs.predict(X_test_scaled)

from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.81      0.73      0.77       422
#      CONFIRMED       0.77      0.82      0.79       450
# FALSE POSITIVE       0.98      0.99      0.99       876
#
#       accuracy                           0.88      1748
#      macro avg       0.85      0.85      0.85      1748
#   weighted avg       0.88      0.88      0.88      1748

# %% [markdown]
# ## Save the Model
# ----------------

# %%
# import joblib
# filename = 'Model_Files/Trees.sav'
# joblib.dump(grid, filename)
