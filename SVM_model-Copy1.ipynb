# %% [markdown]
# Regularization parameter. The strength of the regularization is inversely proportional to C. Must be strictly positive.
# Setting C: C is 1 by default and it’s a reasonable default choice. If you have a lot of noisy observations you should decrease it. It corresponds to regularize more the estimation.
#
# Not much changed when altering feature selection.  Removed 12 features, and the data stayed pretty much the same.

# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\users\test\anaconda3\envs\pythondata\lib\site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\test\anaconda3\envs\pythondata\lib\site-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in c:\users\test\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in c:\users\test\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (1.18.4)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\test\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (0.14.1)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\test\anaconda3\envs\pythondata\lib\site-packages (0.14.1)

# %%
import pandas as pd

# %% [markdown]
#  ## Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

df
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0          CONFIRMED              0              0              0
# 1     FALSE POSITIVE              0              1              0
# 2     FALSE POSITIVE              0              1              0
# 3          CONFIRMED              0              0              0
# 4          CONFIRMED              0              0              0
# ...              ...            ...            ...            ...
# 6986  FALSE POSITIVE              0              0              0
# 6987  FALSE POSITIVE              0              1              1
# 6988       CANDIDATE              0              0              0
# 6989  FALSE POSITIVE              0              0              1
# 6990  FALSE POSITIVE              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 0                 0   54.418383     2.479000e-04    -2.479000e-04
# 1                 0   19.899140     1.490000e-05    -1.490000e-05
# 2                 0    1.736952     2.630000e-07    -2.630000e-07
# 3                 0    2.525592     3.760000e-06    -3.760000e-06
# 4                 0    4.134435     1.050000e-05    -1.050000e-05
# ...             ...         ...              ...              ...
# 6986              1    8.589871     1.846000e-04    -1.846000e-04
# 6987              0    0.527699     1.160000e-07    -1.160000e-07
# 6988              0    1.739849     1.780000e-05    -1.780000e-05
# 6989              0    0.681402     2.430000e-06    -2.430000e-06
# 6990              1    4.856035     6.360000e-05    -6.360000e-05
#
#       koi_time0bk  koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  \
# 0      162.513840          0.003520  ...             -81      4.467
# 1      175.850252          0.000581  ...            -176      4.544
# 2      170.307565          0.000115  ...            -174      4.564
# 3      171.595550          0.001130  ...            -211      4.438
# 4      172.979370          0.001900  ...            -232      4.486
# ...           ...               ...  ...             ...        ...
# 6986   132.016100          0.015700  ...            -152      4.296
# 6987   131.705093          0.000170  ...            -166      4.529
# 6988   133.001270          0.007690  ...            -220      4.444
# 6989   132.181750          0.002850  ...            -236      4.447
# 6990   135.993300          0.010800  ...            -225      4.385
#
#       koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2  \
# 0              0.064          -0.096     0.927          0.105         -0.061
# 1              0.044          -0.176     0.868          0.233         -0.078
# 2              0.053          -0.168     0.791          0.201         -0.067
# 3              0.070          -0.210     1.046          0.334         -0.133
# 4              0.054          -0.229     0.972          0.315         -0.105
# ...              ...             ...       ...            ...            ...
# 6986           0.231          -0.189     1.088          0.313         -0.228
# 6987           0.035          -0.196     0.903          0.237         -0.079
# 6988           0.056          -0.224     1.031          0.341         -0.114
# 6989           0.056          -0.224     1.041          0.341         -0.114
# 6990           0.054          -0.216     1.193          0.410         -0.137
#
#              ra        dec  koi_kepmag
# 0     291.93423  48.141651      15.347
# 1     297.00482  48.134129      15.436
# 2     285.53461  48.285210      15.597
# 3     288.75488  48.226200      15.509
# 4     296.28613  48.224670      15.714
# ...         ...        ...         ...
# 6986  298.74921  46.973351      14.478
# 6987  297.18875  47.093819      14.082
# 6988  286.50937  47.163219      14.757
# 6989  294.16489  47.176281      15.385
# 6990  297.00977  47.121021      14.826
#
# [6991 rows x 41 columns]

# %% [markdown]
# ## Select your features (columns)

# %%
# Set features. This will also be used as your x values.
X = df.drop(columns='koi_disposition')
y = df['koi_disposition']

# %%
from sklearn.ensemble import ExtraTreesClassifier

model = ExtraTreesClassifier()
model.fit(X,y)
#print(model.feature_importances_)

feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(20)
# Out:
# C:\Users\test\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# koi_fpflag_ss        0.180127
# koi_fpflag_co        0.120379
# koi_fpflag_nt        0.116312
# koi_fpflag_ec        0.060025
# koi_duration_err2    0.032395
# koi_depth            0.031983
# koi_duration_err1    0.029641
# koi_model_snr        0.027997
# koi_steff_err2       0.024903
# koi_time0bk_err2     0.024788
# koi_period_err1      0.017397
# koi_duration         0.017079
# koi_time0bk_err1     0.016298
# koi_period_err2      0.015670
# koi_period           0.015653
# koi_teq              0.014083
# koi_slogg_err2       0.013597
# koi_prad_err1        0.013298
# koi_impact_err1      0.012939
# koi_time0bk          0.012873
# dtype: float64

# %%
# Xsel = df[['koi_fpflag_ss', 'koi_fpflag_nt', 'koi_fpflag_co', 'koi_fpflag_ec', 'koi_model_snr',
#            'koi_duration_err1', 'koi_duration_err2', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_steff_err1',
#            'koi_depth', 'koi_period', 'koi_duration', 'koi_period_err1']]
# Xsel
Xsel = X.drop(['koi_impact_err2', 'koi_depth_err1', 'koi_depth_err2', 'koi_insol_err2', 'koi_prad_err2',
              'koi_insol', 'koi_prad', 'koi_prad_err1', 'koi_insol_err1', 'koi_kepmag', 'koi_time0bk'], axis=1)
Xsel
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0   54.418383
# 1                 0              1              0              0   19.899140
# 2                 0              1              0              0    1.736952
# 3                 0              0              0              0    2.525592
# 4                 0              0              0              0    4.134435
# ...             ...            ...            ...            ...         ...
# 6986              0              0              0              1    8.589871
# 6987              0              1              1              0    0.527699
# 6988              0              0              0              0    1.739849
# 6989              0              0              1              0    0.681402
# 6990              0              0              1              1    4.856035
#
#       koi_period_err1  koi_period_err2  koi_time0bk_err1  koi_time0bk_err2  \
# 0        2.479000e-04    -2.479000e-04          0.003520         -0.003520
# 1        1.490000e-05    -1.490000e-05          0.000581         -0.000581
# 2        2.630000e-07    -2.630000e-07          0.000115         -0.000115
# 3        3.760000e-06    -3.760000e-06          0.001130         -0.001130
# 4        1.050000e-05    -1.050000e-05          0.001900         -0.001900
# ...               ...              ...               ...               ...
# 6986     1.846000e-04    -1.846000e-04          0.015700         -0.015700
# 6987     1.160000e-07    -1.160000e-07          0.000170         -0.000170
# 6988     1.780000e-05    -1.780000e-05          0.007690         -0.007690
# 6989     2.430000e-06    -2.430000e-06          0.002850         -0.002850
# 6990     6.360000e-05    -6.360000e-05          0.010800         -0.010800
#
#       koi_impact  ...  koi_steff_err1  koi_steff_err2  koi_slogg  \
# 0          0.586  ...              81             -81      4.467
# 1          0.969  ...             158            -176      4.544
# 2          1.276  ...             157            -174      4.564
# 3          0.701  ...             169            -211      4.438
# 4          0.762  ...             189            -232      4.486
# ...          ...  ...             ...             ...        ...
# 6986       0.765  ...             169            -152      4.296
# 6987       1.252  ...             139            -166      4.529
# 6988       0.043  ...             165            -220      4.444
# 6989       0.147  ...             193            -236      4.447
# 6990       0.134  ...             158            -225      4.385
#
#       koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2  \
# 0              0.064          -0.096     0.927          0.105         -0.061
# 1              0.044          -0.176     0.868          0.233         -0.078
# 2              0.053          -0.168     0.791          0.201         -0.067
# 3              0.070          -0.210     1.046          0.334         -0.133
# 4              0.054          -0.229     0.972          0.315         -0.105
# ...              ...             ...       ...            ...            ...
# 6986           0.231          -0.189     1.088          0.313         -0.228
# 6987           0.035          -0.196     0.903          0.237         -0.079
# 6988           0.056          -0.224     1.031          0.341         -0.114
# 6989           0.056          -0.224     1.041          0.341         -0.114
# 6990           0.054          -0.216     1.193          0.410         -0.137
#
#              ra        dec
# 0     291.93423  48.141651
# 1     297.00482  48.134129
# 2     285.53461  48.285210
# 3     288.75488  48.226200
# 4     296.28613  48.224670
# ...         ...        ...
# 6986  298.74921  46.973351
# 6987  297.18875  47.093819
# 6988  286.50937  47.163219
# 6989  294.16489  47.176281
# 6990  297.00977  47.121021
#
# [6991 rows x 29 columns]

# %% [markdown]
# ## Create a Train Test Split
# *Use koi_disposition for the y values*

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(Xsel, y, random_state = 1, stratify = y)

# %% [markdown]
# ## Pre-processing
# *Scale the data using the MinMaxScaler and perform some feature selection*

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler

X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Train the Model
# ---------------

# %%
from sklearn.svm import SVC
svm_model = SVC(kernel='linear')
svm_model.fit(X_train_scaled, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
print(f"Training Data Score: {svm_model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {svm_model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8432195308029754
# Testing Data Score: 0.8403890160183066

# %% [markdown]
# ## Hyperparameter Tuning
# *Use GridSearchCV to tune the model's parameters*

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
#param_grid = {'C':[1,5,10], 'gamma':[0.0001,0.001,0.01]} # c 10, gamma .0001 .86801

# param_grid = [
#   {'C': [1, 10, 100, 1000], 'kernel': ['linear']},
#   {'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001], 'kernel': ['rbf']},
#  ] # c 1000, kernel linear, .890903
# param_grid = {'kernel': ['linear', 'rbf', 'poly']} # poly
param_grid = {'C': [1, 5, 10, 2500], 'tol': [.02]} #0.8924293583856672


grid = GridSearchCV(svm_model, param_grid, verbose=3)

# {'C': 2500, 'degree': 1}
# 0.8926209257817332

# %%
# Train the model with GridSearch
gs = grid.fit(X_train_scaled,y_train)
# Out:
# C:\Users\test\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [CV] C=1, tol=0.02 ...................................................
# [CV] ....................... C=1, tol=0.02, score=0.854, total=   0.3s
# [CV] C=1, tol=0.02 ...................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV] ....................... C=1, tol=0.02, score=0.838, total=   0.2s
# [CV] C=1, tol=0.02 ...................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.4s remaining:    0.0s
# [CV] ....................... C=1, tol=0.02, score=0.826, total=   0.2s
# [CV] C=5, tol=0.02 ...................................................
# [CV] ....................... C=5, tol=0.02, score=0.870, total=   0.3s
# [CV] C=5, tol=0.02 ...................................................
# [CV] ....................... C=5, tol=0.02, score=0.862, total=   0.2s
# [CV] C=5, tol=0.02 ...................................................
# [CV] ....................... C=5, tol=0.02, score=0.853, total=   0.4s
# [CV] C=10, tol=0.02 ..................................................
# [CV] ...................... C=10, tol=0.02, score=0.874, total=   0.2s
# [CV] C=10, tol=0.02 ..................................................
# [CV] ...................... C=10, tol=0.02, score=0.863, total=   0.2s
# [CV] C=10, tol=0.02 ..................................................
# [CV] ...................... C=10, tol=0.02, score=0.857, total=   0.3s
# [CV] C=2500, tol=0.02 ................................................
# [CV] .................... C=2500, tol=0.02, score=0.902, total=   1.0s
# [CV] C=2500, tol=0.02 ................................................
# [CV] .................... C=2500, tol=0.02, score=0.880, total=   0.9s
# [CV] C=2500, tol=0.02 ................................................
# [CV] .................... C=2500, tol=0.02, score=0.897, total=   0.8s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    5.0s finished

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 2500, 'tol': 0.02}
# 0.8931909212283045

# %%
predictions = gs.predict(X_test_scaled)

from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.82      0.70      0.76       422
#      CONFIRMED       0.76      0.83      0.79       450
# FALSE POSITIVE       0.98      1.00      0.99       876
#
#       accuracy                           0.88      1748
#      macro avg       0.85      0.84      0.85      1748
#   weighted avg       0.88      0.88      0.88      1748

# %% [markdown]
# ## Save the Model
# ----------------

# %%
# # save your model by updating "your_name" with your name
# # and "your_model" with your model variable
# # be sure to turn this in to BCS
# # if joblib fails to import, try running the command to install in terminal/git-bash
# import joblib
# filename = 'Model_Files/SVM.sav'
# joblib.dump(grid, filename)
# Out:
# ['Model_Files/SVM.sav']
