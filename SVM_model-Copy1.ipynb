# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\users\test\anaconda3\envs\may2\lib\site-packages (0.0)
# ...

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib

# %%
import pandas as pd

# %% [markdown]
#  ## Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %% [markdown]
# ## Select your features (columns)

# %%
# Set features. This will also be used as your x values.
X = df.drop(columns='koi_disposition')
y = df['koi_disposition']

# %%
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif

bestfeatures = SelectKBest(score_func=f_classif, k=2)
fit = bestfeatures.fit(X, y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

featureScores = pd.concat([dfcolumns, dfscores], axis=1)
featureScores.columns = ['Specs', 'Score']
print(featureScores.nlargest(40, 'Score'))
# Out:
#                 Specs        Score
# 1       koi_fpflag_ss  1432.706256
# 2       koi_fpflag_co  1159.458615
# 0       koi_fpflag_nt   736.896271
# 29     koi_steff_err1   649.421795
# 3       koi_fpflag_ec   576.060340
# 30     koi_steff_err2   499.942313
# 16          koi_depth   278.062703
# 22            koi_teq   276.736364
# 33     koi_slogg_err2   234.049828
# 26      koi_model_snr   231.814329
# 27   koi_tce_plnt_num   167.707268
# 28          koi_steff   133.165623
# 15  koi_duration_err2   115.763593
# 14  koi_duration_err1   115.763593
# 37                 ra   104.246030
# 13       koi_duration    96.139824
# 31          koi_slogg    91.474329
# 32     koi_slogg_err1    87.106074
# 9    koi_time0bk_err2    82.221813
# 8    koi_time0bk_err1    82.221813
# 4          koi_period    79.357777
# 5     koi_period_err1    67.820794
# 6     koi_period_err2    67.820794
# 35      koi_srad_err1    65.049086
# 11    koi_impact_err1    46.411216
# 38                dec    42.671911
# ...

# %%
# Xsel = df[['koi_fpflag_ss', 'koi_fpflag_co', 'koi_fpflag_nt', 'koi_steff_err1',
#           'koi_fpflag_ec', 'koi_steff_err2', 'koi_depth', 'koi_teq', 'koi_slogg_err2', 'koi_model_snr']]
# Xsel
Xsel = X.drop(['koi_impact_err2', 'koi_depth_err1', 'koi_depth_err2', 'koi_insol_err2', 'koi_prad_err2',
              'koi_insol', 'koi_prad', 'koi_prad_err1', 'koi_insol_err1', 'koi_kepmag', 'koi_time0bk'], axis=1)
Xsel
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0   54.418383
# 1                 0              1              0              0   19.899140
# 2                 0              1              0              0    1.736952
# 3                 0              0              0              0    2.525592
# 4                 0              0              0              0    4.134435
# ...             ...            ...            ...            ...         ...
# 6986              0              0              0              1    8.589871
# 6987              0              1              1              0    0.527699
# 6988              0              0              0              0    1.739849
# 6989              0              0              1              0    0.681402
# 6990              0              0              1              1    4.856035
#
# ...

# %% [markdown]
# ## Create a Train Test Split
# *Use koi_disposition for the y values*

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(Xsel, y, random_state = 1, stratify = y)

# %% [markdown]
# ## Pre-processing
# *Scale the data using the MinMaxScaler and perform some feature selection*

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler

X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Train the Model
# ---------------

# %%
from sklearn.svm import SVC
svm_model = SVC(kernel='linear')
svm_model.fit(X_train_scaled, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
print(f"Training Data Score: {svm_model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {svm_model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8432195308029754
# Testing Data Score: 0.8403890160183066

# %% [markdown]
# ## Hyperparameter Tuning
# *Use GridSearchCV to tune the model's parameters*

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
# param_grid = {'C':[1,5,20], 
#               'kernel': ['linear', 'poly', 'rbf'],
#               'tol': [.001, .0001],
#               'degree': [1, 2, 3]} # 
param_grid = {'C': [2500], 'degree': [1], 'gamma': [0, 1]}

# param_grid = [
#   {'C': [1, 10, 100, 1000], 'kernel': ['linear']},
#   {'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001], 'kernel': ['rbf']},
#  ] # c 1000, kernel linear, .890903
# param_grid = {'kernel': ['linear', 'rbf', 'poly']} # poly
#param_grid = {'C': [2500], 'kernel': ['linear']} #0.8924293583856672
#param_grid = {'C': [2500], 'kernel': ['linear'],
             #'class_weight': ['balanced'], 'tol': [.02]} #0.8933835568589495 
# param_grid = [
#   {'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001], 'kernel': ['rbf']},
#  ]
grid = GridSearchCV(svm_model, param_grid, verbose=3)
#{'C': 20, 'degree': 3, 'kernel': 'poly', 'tol': 0.001}
#0.8792672410656458

# {'C': 2500, 'degree': 1}
# 0.8926209257817332

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled,y_train)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV] C=2500, degree=1, gamma=0 .......................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ........... C=2500, degree=1, gamma=0, score=0.910, total=  10.6s
# [CV] C=2500, degree=1, gamma=0 .......................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.5s remaining:    0.0s
# [CV] ........... C=2500, degree=1, gamma=0, score=0.883, total=   9.5s
# [CV] C=2500, degree=1, gamma=0 .......................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   20.0s remaining:    0.0s
# [CV] ........... C=2500, degree=1, gamma=0, score=0.873, total=  12.0s
# [CV] C=2500, degree=1, gamma=0 .......................................
# [CV] ........... C=2500, degree=1, gamma=0, score=0.902, total=  11.9s
# [CV] C=2500, degree=1, gamma=0 .......................................
# ...

# %%
print(grid.best_params_)
print(grid.best_score_)

# %% [markdown]
# ## Save the Model
# ----------------

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'Model_Files/SVM.sav'
joblib.dump(grid, filename)
# Out:
# ['Model_Files/SVM.sav']
